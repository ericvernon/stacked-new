# %%
import numpy as np
import optuna

from sklearn.model_selection import train_test_split
from ucimlrepo import fetch_ucirepo 
from xgboost import XGBClassifier

# %%
connectionist_bench_sonar_mines_vs_rocks = fetch_ucirepo(id=151) 
  
# data (as pandas dataframes) 
X = connectionist_bench_sonar_mines_vs_rocks.data.features.values
y = connectionist_bench_sonar_mines_vs_rocks.data.targets.values.ravel()
  
# metadata 
print(connectionist_bench_sonar_mines_vs_rocks.metadata) 
  
# variable information 
print(connectionist_bench_sonar_mines_vs_rocks.variables)
# Out:
# {'uci_id': 151, 'name': 'Connectionist Bench (Sonar, Mines vs. Rocks)', 'repository_url': 'https://archive.ics.uci.edu/dataset/151/connectionist+bench+sonar+mines+vs+rocks', 'data_url': 'https://archive.ics.uci.edu/static/public/151/data.csv', 'abstract': 'The task is to train a network to discriminate between sonar signals bounced off a metal cylinder and those bounced off a roughly cylindrical rock.', 'area': 'Physics and Chemistry', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 208, 'num_features': 60, 'feature_types': ['Real'], 'demographics': [], 'target_col': ['class'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1988, 'last_updated': None, 'dataset_doi': '10.24432/C5T01Q', 'creators': ['Terry Sejnowski', 'R. Gorman'], 'intro_paper': None, 'additional_info': {'summary': 'The file "sonar.mines" contains 111 patterns obtained by bouncing sonar signals off a metal cylinder at various angles and under various conditions.  The file "sonar.rocks" contains 97 patterns obtained from rocks under similar conditions.  The transmitted sonar signal is a frequency-modulated chirp, rising in frequency.  The data set contains signals obtained from a variety of different aspect angles, spanning 90 degrees for the cylinder and 180 degrees for the rock.\r\n\r\nEach pattern is a set of 60 numbers in the range 0.0 to 1.0.  Each number represents the energy within a particular frequency band, integrated over a certain period of time.  The integration aperture for higher frequencies occur later in time, since these frequencies are transmitted later during the chirp.\r\n\r\nThe label associated with each record contains the letter "R" if the object is a rock and "M" if it is a mine (metal cylinder).  The numbers in the labels are in increasing order of aspect angle, but they do not encode the angle directly.', 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': None, 'citation': None}}
#            name     role         type demographic description units  \
# 0    Attribute1  Feature   Continuous        None        None  None
# 1    Attribute2  Feature   Continuous        None        None  None
# 2    Attribute3  Feature   Continuous        None        None  None
# 3    Attribute4  Feature   Continuous        None        None  None
# 4    Attribute5  Feature   Continuous        None        None  None
# ..          ...      ...          ...         ...         ...   ...
# 56  Attribute57  Feature   Continuous        None        None  None
# 57  Attribute58  Feature   Continuous        None        None  None
# 58  Attribute59  Feature   Continuous        None        None  None
# 59  Attribute60  Feature   Continuous        None        None  None
# 60        class   Target  Categorical        None        None  None
#
#    missing_values
# 0              no
# 1              no
# 2              no
# 3              no
# 4              no
# ..            ...
# 56             no
# 57             no
# 58             no
# 59             no
# 60             no
#
# [61 rows x 7 columns]

# %%
X.shape
# Out:
# (208, 60)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)
y.shape
# Out:
# (208,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)
X_train.shape
# Out:
# (166, 60)

# %%
xgb = XGBClassifier()
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
xgb.score(X_train, y_train)
# Out:
# 1.0

# %%
xgb.score(X_test, y_test)
# Out:
# 0.8571428571428571

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score

def fn(trial):
    max_depth = trial.suggest_int("max_depth", low=4, high=128)
    min_child_weight = trial.suggest_float("min_child_weight", low=0, high=4)
    gamma = trial.suggest_float("gamma", low=0, high=4)
    xgb = XGBClassifier(
        max_depth=max_depth,
        min_child_weight=min_child_weight,
        gamma=gamma,
        random_state=19,
    )
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
    return cross_val_score(xgb, X_train, y_train, cv=cv).mean()

study = optuna.create_study(direction="maximize")
study.optimize(fn, n_trials=100)
# Out:
# [I 2025-07-08 17:57:28,041] A new study created in memory with name: no-name-5dc84b09-d0f4-499b-b1b9-7be069efdd34
# [I 2025-07-08 17:57:28,240] Trial 0 finished with value: 0.8130124777183602 and parameters: {'max_depth': 25, 'min_child_weight': 2.04843129832424, 'gamma': 1.3770767409037248}. Best is trial 0 with value: 0.8130124777183602.
# [I 2025-07-08 17:57:28,395] Trial 1 finished with value: 0.7650623885918003 and parameters: {'max_depth': 121, 'min_child_weight': 0.6927031336488971, 'gamma': 2.149615307898255}. Best is trial 0 with value: 0.8130124777183602.
# [I 2025-07-08 17:57:28,550] Trial 2 finished with value: 0.7531194295900179 and parameters: {'max_depth': 35, 'min_child_weight': 0.8457781759782868, 'gamma': 2.989798097602455}. Best is trial 0 with value: 0.8130124777183602.
# [I 2025-07-08 17:57:28,698] Trial 3 finished with value: 0.8190730837789661 and parameters: {'max_depth': 42, 'min_child_weight': 3.439323256461306, 'gamma': 0.23080045920319936}. Best is trial 3 with value: 0.8190730837789661.
# [I 2025-07-08 17:57:28,818] Trial 4 finished with value: 0.8069518716577541 and parameters: {'max_depth': 104, 'min_child_weight': 3.8543233975466467, 'gamma': 2.1698806988777917}. Best is trial 3 with value: 0.8190730837789661.
# [I 2025-07-08 17:57:28,952] Trial 5 finished with value: 0.7830659536541891 and parameters: {'max_depth': 101, 'min_child_weight': 2.50175684774464, 'gamma': 0.8165926666949814}. Best is trial 3 with value: 0.8190730837789661.
# [I 2025-07-08 17:57:29,082] Trial 6 finished with value: 0.8010695187165776 and parameters: {'max_depth': 8, 'min_child_weight': 3.1527319201434283, 'gamma': 2.541207948998928}. Best is trial 3 with value: 0.8190730837789661.
# [I 2025-07-08 17:57:29,221] Trial 7 finished with value: 0.8012477718360073 and parameters: {'max_depth': 14, 'min_child_weight': 2.64212177558387, 'gamma': 0.32267898525862115}. Best is trial 3 with value: 0.8190730837789661.
# [I 2025-07-08 17:57:29,369] Trial 8 finished with value: 0.8192513368983958 and parameters: {'max_depth': 66, 'min_child_weight': 2.340978960751261, 'gamma': 0.40862622345677657}. Best is trial 8 with value: 0.8192513368983958.
# [I 2025-07-08 17:57:29,510] Trial 9 finished with value: 0.7650623885918003 and parameters: {'max_depth': 29, 'min_child_weight': 1.25568766485455, 'gamma': 3.6990103245072268}. Best is trial 8 with value: 0.8192513368983958.
# [I 2025-07-08 17:57:29,680] Trial 10 finished with value: 0.7472370766488413 and parameters: {'max_depth': 68, 'min_child_weight': 0.16870165384001323, 'gamma': 1.273637504334365}. Best is trial 8 with value: 0.8192513368983958.
# [I 2025-07-08 17:57:29,830] Trial 11 finished with value: 0.8249554367201426 and parameters: {'max_depth': 59, 'min_child_weight': 3.9659577076051358, 'gamma': 0.151520151667352}. Best is trial 11 with value: 0.8249554367201426.
# [I 2025-07-08 17:57:30,000] Trial 12 finished with value: 0.8130124777183602 and parameters: {'max_depth': 67, 'min_child_weight': 1.5782721994164124, 'gamma': 0.13939935631901376}. Best is trial 11 with value: 0.8249554367201426.
# [I 2025-07-08 17:57:30,140] Trial 13 finished with value: 0.8310160427807487 and parameters: {'max_depth': 54, 'min_child_weight': 3.830895073616026, 'gamma': 0.8976462684355796}. Best is trial 13 with value: 0.8310160427807487.
# [I 2025-07-08 17:57:30,373] Trial 14 finished with value: 0.8253119429590019 and parameters: {'max_depth': 52, 'min_child_weight': 3.9989729585768954, 'gamma': 1.076207868638694}. Best is trial 13 with value: 0.8310160427807487.
# [I 2025-07-08 17:57:30,508] Trial 15 finished with value: 0.7830659536541891 and parameters: {'max_depth': 48, 'min_child_weight': 3.129769242824714, 'gamma': 1.385714581670994}. Best is trial 13 with value: 0.8310160427807487.
# [I 2025-07-08 17:57:30,644] Trial 16 finished with value: 0.8131907308377897 and parameters: {'max_depth': 82, 'min_child_weight': 3.5034210308487843, 'gamma': 0.9231288416411895}. Best is trial 13 with value: 0.8310160427807487.
# [I 2025-07-08 17:57:30,783] Trial 17 finished with value: 0.7827094474153299 and parameters: {'max_depth': 86, 'min_child_weight': 2.804625173493211, 'gamma': 1.6991884655046223}. Best is trial 13 with value: 0.8310160427807487.
# [I 2025-07-08 17:57:30,934] Trial 18 finished with value: 0.8069518716577541 and parameters: {'max_depth': 49, 'min_child_weight': 3.543236738834238, 'gamma': 0.8244729937260687}. Best is trial 13 with value: 0.8310160427807487.
# [I 2025-07-08 17:57:31,070] Trial 19 finished with value: 0.7950089126559716 and parameters: {'max_depth': 53, 'min_child_weight': 3.0003627170115834, 'gamma': 1.7589101757940782}. Best is trial 13 with value: 0.8310160427807487.
# [I 2025-07-08 17:57:31,204] Trial 20 finished with value: 0.8008912655971481 and parameters: {'max_depth': 81, 'min_child_weight': 3.932280461020145, 'gamma': 0.7030954490813258}. Best is trial 13 with value: 0.8310160427807487.
# [I 2025-07-08 17:57:31,349] Trial 21 finished with value: 0.8130124777183602 and parameters: {'max_depth': 61, 'min_child_weight': 3.988435006185014, 'gamma': 0.03259671425869748}. Best is trial 13 with value: 0.8310160427807487.
# [I 2025-07-08 17:57:31,485] Trial 22 finished with value: 0.7950089126559716 and parameters: {'max_depth': 58, 'min_child_weight': 3.5826178471957175, 'gamma': 1.1421319071846574}. Best is trial 13 with value: 0.8310160427807487.
# [I 2025-07-08 17:57:31,644] Trial 23 finished with value: 0.8491978609625669 and parameters: {'max_depth': 40, 'min_child_weight': 3.7236874522214407, 'gamma': 0.4786051583591471}. Best is trial 23 with value: 0.8491978609625669.
# [I 2025-07-08 17:57:31,796] Trial 24 finished with value: 0.8071301247771837 and parameters: {'max_depth': 40, 'min_child_weight': 3.2981751129408936, 'gamma': 0.45983555123481645}. Best is trial 23 with value: 0.8491978609625669.
# [I 2025-07-08 17:57:31,938] Trial 25 finished with value: 0.7950089126559716 and parameters: {'max_depth': 26, 'min_child_weight': 3.679838212929345, 'gamma': 0.6202226876117606}. Best is trial 23 with value: 0.8491978609625669.
# [I 2025-07-08 17:57:32,072] Trial 26 finished with value: 0.7950089126559716 and parameters: {'max_depth': 18, 'min_child_weight': 2.910356571614403, 'gamma': 1.0549963088773087}. Best is trial 23 with value: 0.8491978609625669.
# [I 2025-07-08 17:57:32,214] Trial 27 finished with value: 0.7951871657754012 and parameters: {'max_depth': 75, 'min_child_weight': 1.9723046783459943, 'gamma': 1.6684007281006235}. Best is trial 23 with value: 0.8491978609625669.
# [I 2025-07-08 17:57:32,356] Trial 28 finished with value: 0.8431372549019608 and parameters: {'max_depth': 36, 'min_child_weight': 3.7237141435739116, 'gamma': 0.5807271794096601}. Best is trial 23 with value: 0.8491978609625669.
# [I 2025-07-08 17:57:32,510] Trial 29 finished with value: 0.8069518716577541 and parameters: {'max_depth': 37, 'min_child_weight': 2.1176872324058955, 'gamma': 1.492608952227704}. Best is trial 23 with value: 0.8491978609625669.
# [I 2025-07-08 17:57:32,649] Trial 30 finished with value: 0.8313725490196079 and parameters: {'max_depth': 4, 'min_child_weight': 3.3004638104454407, 'gamma': 0.5724103177501793}. Best is trial 23 with value: 0.8491978609625669.
# [I 2025-07-08 17:57:32,789] Trial 31 finished with value: 0.837433155080214 and parameters: {'max_depth': 4, 'min_child_weight': 3.3163219744539605, 'gamma': 0.5774223381365202}. Best is trial 23 with value: 0.8491978609625669.
# [I 2025-07-08 17:57:32,930] Trial 32 finished with value: 0.7951871657754012 and parameters: {'max_depth': 7, 'min_child_weight': 3.1611177568113584, 'gamma': 0.5132732017182879}. Best is trial 23 with value: 0.8491978609625669.
# [I 2025-07-08 17:57:33,067] Trial 33 finished with value: 0.8495543672014261 and parameters: {'max_depth': 16, 'min_child_weight': 3.314989174758743, 'gamma': 0.5515520864263056}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:33,200] Trial 34 finished with value: 0.7588235294117649 and parameters: {'max_depth': 18, 'min_child_weight': 2.72844564179699, 'gamma': 3.21210655629429}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:33,359] Trial 35 finished with value: 0.8251336898395722 and parameters: {'max_depth': 32, 'min_child_weight': 3.6853900995198803, 'gamma': 0.3061235604967608}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:33,490] Trial 36 finished with value: 0.7770053475935829 and parameters: {'max_depth': 22, 'min_child_weight': 3.416386106676304, 'gamma': 2.012753452815128}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:33,623] Trial 37 finished with value: 0.8007130124777184 and parameters: {'max_depth': 13, 'min_child_weight': 2.4667295882532545, 'gamma': 2.427147416724366}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:33,761] Trial 38 finished with value: 0.7887700534759359 and parameters: {'max_depth': 44, 'min_child_weight': 3.747300613004437, 'gamma': 0.7081634360016289}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:33,908] Trial 39 finished with value: 0.8311942959001783 and parameters: {'max_depth': 126, 'min_child_weight': 3.353902571990468, 'gamma': 0.2721394657435615}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:34,046] Trial 40 finished with value: 0.8313725490196079 and parameters: {'max_depth': 24, 'min_child_weight': 3.022390512109039, 'gamma': 1.2500852810989618}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:34,198] Trial 41 finished with value: 0.8190730837789661 and parameters: {'max_depth': 4, 'min_child_weight': 3.3790068143441547, 'gamma': 0.6115246030068449}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:34,345] Trial 42 finished with value: 0.7951871657754012 and parameters: {'max_depth': 13, 'min_child_weight': 3.218253668508931, 'gamma': 0.46829260240382653}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:34,496] Trial 43 finished with value: 0.8190730837789661 and parameters: {'max_depth': 4, 'min_child_weight': 3.6922746172810306, 'gamma': 0.0033328134771615225}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:34,658] Trial 44 finished with value: 0.7771836007130124 and parameters: {'max_depth': 32, 'min_child_weight': 0.8264940735010167, 'gamma': 0.8122325662750092}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:34,850] Trial 45 finished with value: 0.7953654188948308 and parameters: {'max_depth': 11, 'min_child_weight': 0.25523589166499105, 'gamma': 0.35218304671013234}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:35,003] Trial 46 finished with value: 0.7586452762923352 and parameters: {'max_depth': 18, 'min_child_weight': 2.5974361224891336, 'gamma': 0.9911650087522238}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:35,169] Trial 47 finished with value: 0.8188948306595366 and parameters: {'max_depth': 29, 'min_child_weight': 1.45586386213813, 'gamma': 0.20625378067676076}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:35,305] Trial 48 finished with value: 0.7650623885918003 and parameters: {'max_depth': 21, 'min_child_weight': 2.8537160808773048, 'gamma': 3.0207467633958225}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:35,445] Trial 49 finished with value: 0.8069518716577541 and parameters: {'max_depth': 9, 'min_child_weight': 3.5255142416905936, 'gamma': 0.5988161246276187}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:35,575] Trial 50 finished with value: 0.7768270944741532 and parameters: {'max_depth': 100, 'min_child_weight': 3.0482116285969054, 'gamma': 3.8175352051325655}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:35,713] Trial 51 finished with value: 0.8194295900178254 and parameters: {'max_depth': 25, 'min_child_weight': 3.263121190621812, 'gamma': 1.240322201884676}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:35,843] Trial 52 finished with value: 0.8008912655971481 and parameters: {'max_depth': 37, 'min_child_weight': 3.769231917388524, 'gamma': 1.4350464477249072}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:35,983] Trial 53 finished with value: 0.8130124777183602 and parameters: {'max_depth': 44, 'min_child_weight': 3.081053671951432, 'gamma': 0.8150296370572677}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:36,117] Trial 54 finished with value: 0.801247771836007 and parameters: {'max_depth': 16, 'min_child_weight': 3.499627058862356, 'gamma': 1.152966345087211}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:36,273] Trial 55 finished with value: 0.8253119429590019 and parameters: {'max_depth': 22, 'min_child_weight': 2.9302130657419414, 'gamma': 0.16308450769369354}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:36,409] Trial 56 finished with value: 0.8190730837789661 and parameters: {'max_depth': 8, 'min_child_weight': 3.8295300606869604, 'gamma': 0.9466571811207749}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:36,549] Trial 57 finished with value: 0.8071301247771837 and parameters: {'max_depth': 28, 'min_child_weight': 3.575228482722697, 'gamma': 0.7237531435580367}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:36,695] Trial 58 finished with value: 0.7889483065953655 and parameters: {'max_depth': 4, 'min_child_weight': 2.1543152085163846, 'gamma': 0.4219947566651483}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:36,841] Trial 59 finished with value: 0.8131907308377897 and parameters: {'max_depth': 14, 'min_child_weight': 3.2595984553168416, 'gamma': 0.5390273728254427}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:36,981] Trial 60 finished with value: 0.8008912655971481 and parameters: {'max_depth': 35, 'min_child_weight': 3.4040900330295942, 'gamma': 1.2893565973897554}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:37,132] Trial 61 finished with value: 0.837433155080214 and parameters: {'max_depth': 93, 'min_child_weight': 3.3130452674464976, 'gamma': 0.2705703798447782}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:37,294] Trial 62 finished with value: 0.8131907308377897 and parameters: {'max_depth': 105, 'min_child_weight': 3.1208309261462692, 'gamma': 0.35820153239515085}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:37,442] Trial 63 finished with value: 0.8130124777183602 and parameters: {'max_depth': 96, 'min_child_weight': 3.8691887899256026, 'gamma': 0.159843015324868}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:37,585] Trial 64 finished with value: 0.8010695187165775 and parameters: {'max_depth': 119, 'min_child_weight': 3.6228620494965056, 'gamma': 0.7022721809996166}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:37,752] Trial 65 finished with value: 0.7951871657754012 and parameters: {'max_depth': 111, 'min_child_weight': 3.466430851986765, 'gamma': 0.08322679951417045}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:37,906] Trial 66 finished with value: 0.8131907308377897 and parameters: {'max_depth': 23, 'min_child_weight': 2.744221661964827, 'gamma': 0.8797023346663008}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:38,066] Trial 67 finished with value: 0.7950089126559716 and parameters: {'max_depth': 89, 'min_child_weight': 1.8846663942315172, 'gamma': 0.26459620192611605}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:38,215] Trial 68 finished with value: 0.8190730837789661 and parameters: {'max_depth': 48, 'min_child_weight': 2.980769968511289, 'gamma': 0.4875384705143128}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:38,352] Trial 69 finished with value: 0.8069518716577541 and parameters: {'max_depth': 75, 'min_child_weight': 3.3022120978350546, 'gamma': 1.8453050465548366}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:38,492] Trial 70 finished with value: 0.8010695187165776 and parameters: {'max_depth': 10, 'min_child_weight': 3.1957688733341234, 'gamma': 1.0485389853830207}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:38,641] Trial 71 finished with value: 0.8251336898395722 and parameters: {'max_depth': 119, 'min_child_weight': 3.3478963774480355, 'gamma': 0.3767516116445263}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:38,797] Trial 72 finished with value: 0.8372549019607843 and parameters: {'max_depth': 62, 'min_child_weight': 3.631465101622267, 'gamma': 0.2466874212137682}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:38,937] Trial 73 finished with value: 0.8251336898395722 and parameters: {'max_depth': 63, 'min_child_weight': 3.674186256867067, 'gamma': 0.5455737285018154}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:39,076] Trial 74 finished with value: 0.8130124777183602 and parameters: {'max_depth': 55, 'min_child_weight': 3.8719182475535523, 'gamma': 0.7219537964987469}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:39,230] Trial 75 finished with value: 0.8249554367201426 and parameters: {'max_depth': 72, 'min_child_weight': 3.5847631310722923, 'gamma': 0.0579060749824295}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:39,380] Trial 76 finished with value: 0.8188948306595366 and parameters: {'max_depth': 39, 'min_child_weight': 3.76480739768968, 'gamma': 0.2608102003717295}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:39,519] Trial 77 finished with value: 0.8313725490196079 and parameters: {'max_depth': 34, 'min_child_weight': 3.9988088315788324, 'gamma': 0.6357184133194552}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:39,664] Trial 78 finished with value: 0.8131907308377897 and parameters: {'max_depth': 19, 'min_child_weight': 3.4385182457685954, 'gamma': 0.42859851208592026}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:39,814] Trial 79 finished with value: 0.7834224598930483 and parameters: {'max_depth': 15, 'min_child_weight': 1.1582558033866974, 'gamma': 2.569075143076397}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:39,959] Trial 80 finished with value: 0.8192513368983958 and parameters: {'max_depth': 43, 'min_child_weight': 2.3649963504477944, 'gamma': 1.5924317679810378}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:40,103] Trial 81 finished with value: 0.8007130124777184 and parameters: {'max_depth': 32, 'min_child_weight': 3.9213327852912743, 'gamma': 0.6256273553500942}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:40,241] Trial 82 finished with value: 0.7827094474153299 and parameters: {'max_depth': 29, 'min_child_weight': 3.777263027446851, 'gamma': 0.8054081182412463}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:40,385] Trial 83 finished with value: 0.8010695187165775 and parameters: {'max_depth': 32, 'min_child_weight': 3.6222710732500034, 'gamma': 0.6608353146779072}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:40,544] Trial 84 finished with value: 0.8372549019607843 and parameters: {'max_depth': 6, 'min_child_weight': 3.9970843648886443, 'gamma': 0.5295240249535704}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:40,688] Trial 85 finished with value: 0.8192513368983958 and parameters: {'max_depth': 7, 'min_child_weight': 3.506830396544314, 'gamma': 0.32489258252206255}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:40,832] Trial 86 finished with value: 0.8012477718360073 and parameters: {'max_depth': 6, 'min_child_weight': 3.164242710367911, 'gamma': 0.5313337049535833}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:40,985] Trial 87 finished with value: 0.8192513368983958 and parameters: {'max_depth': 11, 'min_child_weight': 3.7181430262613326, 'gamma': 0.20844362152853685}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:41,144] Trial 88 finished with value: 0.8190730837789661 and parameters: {'max_depth': 12, 'min_child_weight': 3.0153268637127226, 'gamma': 0.10870533347153938}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:41,284] Trial 89 finished with value: 0.8069518716577541 and parameters: {'max_depth': 16, 'min_child_weight': 3.3715036673848644, 'gamma': 0.7998261704468368}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:41,441] Trial 90 finished with value: 0.8130124777183602 and parameters: {'max_depth': 26, 'min_child_weight': 2.8560898384349325, 'gamma': 0.43276164427087904}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:41,604] Trial 91 finished with value: 0.8067736185383245 and parameters: {'max_depth': 49, 'min_child_weight': 3.9466133739920886, 'gamma': 0.5876765229120653}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:41,760] Trial 92 finished with value: 0.7946524064171123 and parameters: {'max_depth': 83, 'min_child_weight': 3.945587472774824, 'gamma': 0.9290855607210495}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:41,953] Trial 93 finished with value: 0.7946524064171123 and parameters: {'max_depth': 41, 'min_child_weight': 3.878592667198792, 'gamma': 0.48946539291984553}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:42,119] Trial 94 finished with value: 0.8310160427807487 and parameters: {'max_depth': 20, 'min_child_weight': 3.7993653476128335, 'gamma': 0.30429765631225847}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:42,255] Trial 95 finished with value: 0.7950089126559716 and parameters: {'max_depth': 46, 'min_child_weight': 3.643792337959314, 'gamma': 1.1332684597883742}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:42,399] Trial 96 finished with value: 0.7828877005347593 and parameters: {'max_depth': 6, 'min_child_weight': 3.9887111522973653, 'gamma': 0.7263948782452265}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:42,541] Trial 97 finished with value: 0.8131907308377897 and parameters: {'max_depth': 35, 'min_child_weight': 3.5344898228583035, 'gamma': 0.36172553292904874}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:42,678] Trial 98 finished with value: 0.7950089126559714 and parameters: {'max_depth': 24, 'min_child_weight': 3.444522827883468, 'gamma': 1.003132326737628}. Best is trial 33 with value: 0.8495543672014261.
# [I 2025-07-08 17:57:42,840] Trial 99 finished with value: 0.777361853832442 and parameters: {'max_depth': 4, 'min_child_weight': 0.42279616461752223, 'gamma': 0.6355214339031612}. Best is trial 33 with value: 0.8495543672014261.

# %%
xgb = XGBClassifier(**study.best_params)
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=0.5515520864263056, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=16,
#               max_leaves=None, min_child_weight=3.314989174758743, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
xgb.score(X_train, y_train)
# Out:
# 1.0

# %%
xgb.score(X_test, y_test)
# Out:
# 0.9047619047619048

# %%
X_subtrain, X_valid, y_subtrain, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=3)

# %%
xgb2 = XGBClassifier(**study.best_params)
xgb2.fit(X_subtrain, y_subtrain)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=0.5515520864263056, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=16,
#               max_leaves=None, min_child_weight=3.314989174758743, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
xgb2.score(X_subtrain, y_subtrain)
# Out:
# 1.0

# %%
xgb2.score(X_valid, y_valid)
# Out:
# 0.9411764705882353
